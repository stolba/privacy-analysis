# %%
import sys
import getopt
import os
#from sets import Set
import json
import pprint
import itertools
from graphviz import Digraph
from math import log
import src.searchtree_v2 as st
import src.utils as utils
import csv   
from pathlib import Path

# %%
#compose the logic formula describing the properties of the operators
from sympy import *
    

#helper functions
def getPreSATVariable(op,variable,value):
    var = op+"preVar"+str(variable)+"Val"+str(value)
    sym = symbols(var)
    return sym

def getEffSATVariable(op,variable,value):
    var = op+"effVar"+str(variable)+"Val"+str(value)
    sym = symbols(var)
    return sym

def opInitApplicableInState(opHash):
    formula = True
    for var in range(0,agentPrivateVariables):
        sym = getPreSATVariable(opHash,var,0)
        formula = (formula & sym)
    return formula

def opPrivatelyIndependent(opHash,numOfStates):
    formula = False
    for var in range(0,agentPrivateVariables):
        subformula = True
        for val in range(0,agentDomainSize):
            sym = getPreSATVariable(opHash,var,val)
            subformula = (subformula & sym)
        formula = formula | subformula
    return formula

def opPrivatelyDependent(opHash,numOfStates):
    formula = False
    for var in range(0,agentPrivateVariables):
        subformula1 = True
        subformula2 = True
        for val in range(0,agentDomainSize):
            sym = getPreSATVariable(opHash,var,val)
            subformula1 = subformula1 | sym
            subformula2 = subformula2 | ~sym
        formula = formula | (subformula1 & subformula2)
    return formula

def opPrivatelyNondeterministic(opHash,numOfStates):
    formula = False
    for var in range(0,agentPrivateVariables):
        subformula = False
        for val1 in range(0,agentDomainSize):
            for val2 in range(0,agentDomainSize):
                if val1 != val2:
                    sym1 = getEffSATVariable(opHash,var,val1)
                    sym2 = getEffSATVariable(opHash,var,val2)
                    subformula = subformula | (sym1 & sym2)
        formula = formula | (subformula)
    return formula

# %%
def computeFixedTS(k,l):
    
    sum = 0
    for j in range(k+1):
        sum += (-1)**j * binomial(k,j) * (2**(k-j) - 1)**l
    
#     print("compute all TS between "+str(k)+" pre and "+str(l)+" eff = " + str(sum))
    
    return sum

def computeAllTS(pfree,efree,ptrue,etrue):
    total = 0
    
    pmin = 0
    if ptrue==0:
        pmin=1
        
    emin = 0
    if etrue==0:
        emin=1
        
    for k in range(pmin,pfree+1):
        for l in range(emin,efree+1):
            if k+ptrue>0 and l+etrue >0:
                fixed = binomial(pfree,k) * binomial(efree,l) * computeFixedTS(k+ptrue,l+etrue)
                total += fixed
            
    return total


def evaluateModels(models):
    count = 0;
    maxTotalTS = 0
    
    for model in models:
#         print(model)
        count += 1
        opHash = 'op'

        opTS = 1
        subForEmptyTS = 1
        
        if model == True or model == False:
            return 1

        for var in range(0,agentPrivateVariables):

            freePre = agentDomainSize
            freeEff = agentDomainSize

            posPre = 0
            posEff = 0

            for val in range(0,agentDomainSize):
                preVar = getPreSATVariable(opHash,var,val)
                effVar = getEffSATVariable(opHash,var,val)

                if preVar in model:
                    freePre -= 1
                    if model[preVar] == True:
                        posPre += 1

                if effVar in model:
                    freeEff -=1
                    if model[effVar] == True:
                        posEff += 1

#                 print(opHash+",var="+str(var)+": pre:#"+str(freePre)+",+"+str(posPre))
#                 print(opHash+",var="+str(var)+": eff:#"+str(freeEff)+",+"+str(posEff))

            varTS = computeAllTS(freePre,freeEff,posPre,posEff)

            opTS = opTS * varTS

                
        totalTS = opTS
       
        if totalTS > maxTotalTS:
            maxTotalTS = totalTS
    
    print("Evaluated " + str(count) + " models")
    return maxTotalTS
            
#test:
print(computeAllTS(2,2,0,0))
# Out:
# 15

# %%
#determine RHS based on combinations of properties

#check cache:
cacheCSVFile = "ts_cache.csv"
outCSV = Path(cacheCSVFile)
exists = outCSV.is_file()
found = False


for agentPrivateVariables in range (1,5):
    for agentDomainSize in range(1,5):
        print("Compute: " + str(agentPrivateVariables)+","+str(agentDomainSize))
        
        found = False
        if exists:
            with open("ts_cache.csv") as csvfile:
                reader = csv.DictReader(csvfile)
                for row in reader:
                    if row['agentDomainSize']==str(agentDomainSize) and  row['agentPrivateVariables']==str(agentPrivateVariables):
                        print("Reading from cache file!")
                        print(row)
                        found = True

        if found:
            print("Found!")
            continue
            
        print("ts")
        ts = (2**(agentDomainSize**2) - 1)**agentPrivateVariables 
        print(ts)
        rhs_t = log(ts,2).evalf()

        print("ia")
        f_ia = opInitApplicableInState('op')
        print(f_ia)
        models_ia = satisfiable(f_ia,all_models=True)
        ts_ia = evaluateModels(models_ia)
        print(ts_ia)
        rhs_ia = log(ts_ia,2).evalf()

        print("nia")
        f_nia = ~opInitApplicableInState('op')
        print(f_nia)
        models_nia = satisfiable(f_nia,all_models=True)
        ts_nia = evaluateModels(models_nia)
        print(ts_nia)
        rhs_nia = log(ts_nia,2).evalf()

        print("pi")
        f_pi = opPrivatelyIndependent('op',1)
        print(f_pi)
        models_pi = satisfiable(f_pi,all_models=True)
        ts_pi = evaluateModels(models_pi)
        print(ts_pi)
        rhs_pi = log(ts_pi,2).evalf()

        print("pd")
        f_pd = opPrivatelyDependent('op',1)
        print(f_pd)
        models_pd = satisfiable(f_pd,all_models=True)
        ts_pd = evaluateModels(models_pd)
        print(ts_pd)
        rhs_pd = log(ts_pd,2).evalf()

        print("pn")
        f_pn = opPrivatelyNondeterministic('op',1)
        print(f_pn)
        models_pn = satisfiable(f_pn,all_models=True)
        ts_pn = evaluateModels(models_pn)
        print(ts_pn)
        rhs_pn = log(ts_pn,2).evalf()

        print("ia_pi")
        f_ia_pi = opInitApplicableInState('op') & opPrivatelyIndependent('op',1)
        print(f_ia_pi)
        models_ia_pi = satisfiable(f_ia_pi,all_models=True)
        ts_ia_pi = evaluateModels(models_ia_pi)
        print(ts_ia_pi)
        rhs_ia_pi = log(ts_ia_pi,2).evalf()

        print("nia_pi")
        f_nia_pi = ~opInitApplicableInState('op') & opPrivatelyIndependent('op',1)
        print(f_nia_pi)
        models_nia_pi = satisfiable(f_nia_pi,all_models=True)
        ts_nia_pi = evaluateModels(models_nia_pi)
        print(ts_nia_pi)
        rhs_nia_pi = log(ts_nia_pi,2).evalf()

        print("ia_pd")
        f_ia_pd = opInitApplicableInState('op') & opPrivatelyDependent('op',1)
        print(f_ia_pd)
        models_ia_pd = satisfiable(f_ia_pd,all_models=True)
        ts_ia_pd = evaluateModels(models_ia_pd)
        print(ts_ia_pd)
        rhs_ia_pd = log(ts_ia_pd,2).evalf()

        print("nia_pd")
        f_nia_pd = ~opInitApplicableInState('op') & opPrivatelyDependent('op',1)
        print(f_nia_pd)
        models_nia_pd = satisfiable(f_nia_pd,all_models=True)
        ts_nia_pd = evaluateModels(models_nia_pd)
        print(ts_nia_pd)
        rhs_nia_pd = log(ts_nia_pd,2).evalf()

        print("ia_pn")
        f_ia_pn = opInitApplicableInState('op') & opPrivatelyNondeterministic('op',1)
        print(f_ia_pn)
        models_ia_pn = satisfiable(f_ia_pn,all_models=True)
        ts_ia_pn = evaluateModels(models_ia_pn)
        print(ts_ia_pn)
        rhs_ia_pn = log(ts_ia_pn,2).evalf()

        print("nia_pn")
        f_nia_pn = ~opInitApplicableInState('op') & opPrivatelyNondeterministic('op',1)
        print(f_nia_pn)
        models_nia_pn = satisfiable(f_nia_pn,all_models=True)
        ts_nia_pn = evaluateModels(models_nia_pn)
        print(ts_nia_pn)
        rhs_nia_pn = log(ts_nia_pn,2).evalf()

        print("pi_pn")
        f_pi_pn = opPrivatelyIndependent('op',1) & opPrivatelyNondeterministic('op',1)
        print(f_pi_pn)
        models_pi_pn = satisfiable(f_pi_pn,all_models=True)
        ts_pi_pn = evaluateModels(models_pi_pn)
        print(ts_pi_pn)
        rhs_pi_pn = log(ts_pi_pn,2).evalf()

        print("pd_pn")
        f_pd_pn = opPrivatelyDependent('op',1) & opPrivatelyNondeterministic('op',1)
        print(f_pd_pn)
        models_pd_pn = satisfiable(f_pd_pn,all_models=True)
        ts_pd_pn = evaluateModels(models_pd_pn)
        print(ts_pd_pn)
        rhs_pd_pn = log(ts_pd_pn,2).evalf()

        print("ia_pi_pn")
        f_ia_pi_pn = opInitApplicableInState('op') & opPrivatelyIndependent('op',1) & opPrivatelyNondeterministic('op',1)
        print(f_ia_pi_pn)
        models_ia_pi_pn = satisfiable(f_ia_pi_pn,all_models=True)
        ts_ia_pi_pn = evaluateModels(models_ia_pi_pn)
        print(ts_ia_pi_pn)
        rhs_ia_pi_pn = log(ts_ia_pi_pn,2).evalf()

        print("nia_pi_pn")
        f_nia_pi_pn = ~opInitApplicableInState('op') & opPrivatelyIndependent('op',1) & opPrivatelyNondeterministic('op',1)
        print(f_nia_pi_pn)
        models_nia_pi_pn = satisfiable(f_nia_pi_pn,all_models=True)
        ts_nia_pi_pn = evaluateModels(models_nia_pi_pn)
        print(ts_nia_pi_pn)
        rhs_nia_pi_pn = log(ts_nia_pi_pn,2).evalf()

        print("ia_pd_pn")
        f_ia_pd_pn = opInitApplicableInState('op') & opPrivatelyDependent('op',1) & opPrivatelyNondeterministic('op',1)
        print(f_ia_pd_pn)
        models_ia_pd_pn = satisfiable(f_ia_pd_pn,all_models=True)
        ts_ia_pd_pn = evaluateModels(models_ia_pd_pn)
        print(ts_ia_pd_pn)
        rhs_ia_pd_pn = log(ts_ia_pd_pn,2).evalf()

        print("nia_pd_pn")
        f_nia_pd_pn = ~opInitApplicableInState('op') & opPrivatelyDependent('op',1) & opPrivatelyNondeterministic('op',1)
        print(f_nia_pd_pn)
        models_nia_pd_pn = satisfiable(f_nia_pd_pn,all_models=True)
        ts_nia_pd_pn = evaluateModels(models_nia_pd_pn)
        print(ts_nia_pd_pn)
        rhs_nia_pd_pn = log(ts_nia_pd_pn,2).evalf()
        
        columns=[
            'agentPrivateVariables',
            'agentDomainSize',
            'ts',
            'ia',
            'nia',
            'pi',
            'pd',
            'pn',
            'ia_pi',
            'ia_pd',
            'ia_pn',
            'nia_pi',
            'nia_pd',
            'nia_pn',
            'pi_pn',
            'pd_pn',
            'ia_pi_pn',
            'ia_pd_pn',
            'nia_pi_pn',
            'nia_pd_pn'
        ]

        outCSV = Path(cacheCSVFile)
        exists = outCSV.is_file()

        row = [
            agentPrivateVariables,
            agentDomainSize,
            rhs_t,
            rhs_ia,
            rhs_nia,
            rhs_pi,
            rhs_pd,
            rhs_pn,
            rhs_ia_pi,
            rhs_ia_pd,
            rhs_ia_pn,
            rhs_nia_pi,
            rhs_nia_pd,
            rhs_nia_pn,
            rhs_pi_pn,
            rhs_pd_pn,
            rhs_ia_pi_pn,
            rhs_ia_pd_pn,
            rhs_nia_pi_pn,
            rhs_nia_pd_pn
        ]


        with open(cacheCSVFile, 'a') as f:
            writer = csv.writer(f)
            if not exists:
                writer.writerow(columns)
            writer.writerow(row)
# Out:
# Compute: 1,1
# ts
# 1
# ia
# oppreVar0Val0
# Evaluated 1 models
# 1
# nia
# ~oppreVar0Val0
# Evaluated 1 models
# 0
# pi
# oppreVar0Val0
# Evaluated 1 models
# 1
# pd
# True
# Evaluated 1 models
# 1
# pn
# False
# 1
# ia_pi
# oppreVar0Val0
# Evaluated 1 models
# 1
# nia_pi
# oppreVar0Val0 & ~oppreVar0Val0
# 1
# ia_pd
# oppreVar0Val0
# Evaluated 1 models
# 1
# nia_pd
# ~oppreVar0Val0
# Evaluated 1 models
# 0
# ia_pn
# False
# 1
# nia_pn
# False
# 1
# pi_pn
# False
# 1
# pd_pn
# False
# 1
# ia_pi_pn
# False
# 1
# nia_pi_pn
# False
# 1
# ia_pd_pn
# False
# 1
# nia_pd_pn
# False
# 1
# Compute: 1,2
# ts
# 15
# ia
# oppreVar0Val0
# Evaluated 1 models
# 12
# nia
# ~oppreVar0Val0
# Evaluated 1 models
# 3
# pi
# oppreVar0Val0 & oppreVar0Val1
# Evaluated 1 models
# 9
# pd
# True
# Evaluated 1 models
# 15
# pn
# opeffVar0Val0 & opeffVar0Val1
# Evaluated 1 models
# 9
# ia_pi
# oppreVar0Val0 & oppreVar0Val1
# Evaluated 1 models
# 9
# nia_pi
# oppreVar0Val0 & oppreVar0Val1 & ~oppreVar0Val0
# 1
# ia_pd
# oppreVar0Val0
# Evaluated 1 models
# 12
# nia_pd
# ~oppreVar0Val0
# Evaluated 1 models
# 3
# ia_pn
# opeffVar0Val0 & opeffVar0Val1 & oppreVar0Val0
# Evaluated 1 models
# 8
# nia_pn
# opeffVar0Val0 & opeffVar0Val1 & ~oppreVar0Val0
# Evaluated 1 models
# 1
# pi_pn
# opeffVar0Val0 & opeffVar0Val1 & oppreVar0Val0 & oppreVar0Val1
# Evaluated 1 models
# 7
# pd_pn
# opeffVar0Val0 & opeffVar0Val1
# Evaluated 1 models
# 9
# ia_pi_pn
# opeffVar0Val0 & opeffVar0Val1 & oppreVar0Val0 & oppreVar0Val1
# Evaluated 1 models
# 7
# nia_pi_pn
# opeffVar0Val0 & opeffVar0Val1 & oppreVar0Val0 & oppreVar0Val1 & ~oppreVar0Val0
# 1
# ia_pd_pn
# opeffVar0Val0 & opeffVar0Val1 & oppreVar0Val0
# Evaluated 1 models
# 8
# nia_pd_pn
# opeffVar0Val0 & opeffVar0Val1 & ~oppreVar0Val0
# Evaluated 1 models
# 1
# Compute: 1,3
# ts
# 511
# ia
# oppreVar0Val0
# Evaluated 1 models
# 448
# nia
# ~oppreVar0Val0
# Evaluated 1 models
# 63
# pi
# oppreVar0Val0 & oppreVar0Val1 & oppreVar0Val2
# Evaluated 1 models
# 343
# pd
# True
# Evaluated 1 models
# 511
# pn
# (opeffVar0Val0 & opeffVar0Val1) | (opeffVar0Val0 & opeffVar0Val2) | (opeffVar0Val1 & opeffVar0Val2)
# Evaluated 4 models
# 343
# ia_pi
# oppreVar0Val0 & oppreVar0Val1 & oppreVar0Val2
# Evaluated 1 models
# 343
# nia_pi
# oppreVar0Val0 & oppreVar0Val1 & oppreVar0Val2 & ~oppreVar0Val0
# 1
# ia_pd
# oppreVar0Val0
# Evaluated 1 models
# 448
# nia_pd
# ~oppreVar0Val0
# Evaluated 1 models
# 63
# ia_pn
# oppreVar0Val0 & ((opeffVar0Val0 & opeffVar0Val1) | (opeffVar0Val0 & opeffVar0Val2) | (opeffVar0Val1 & opeffVar0Val2))
# Evaluated 4 models
# 316
# nia_pn
# ~oppreVar0Val0 & ((opeffVar0Val0 & opeffVar0Val1) | (opeffVar0Val0 & opeffVar0Val2) | (opeffVar0Val1 & opeffVar0Val2))
# Evaluated 4 models
# 27
# pi_pn
# oppreVar0Val0 & oppreVar0Val1 & oppreVar0Val2 & ((opeffVar0Val0 & opeffVar0Val1) | (opeffVar0Val0 & opeffVar0Val2) | (opeffVar0Val1 & opeffVar0Val2))
# Evaluated 4 models
# 265
# pd_pn
# (opeffVar0Val0 & opeffVar0Val1) | (opeffVar0Val0 & opeffVar0Val2) | (opeffVar0Val1 & opeffVar0Val2)
# Evaluated 4 models
# 343
# ia_pi_pn
# oppreVar0Val0 & oppreVar0Val1 & oppreVar0Val2 & ((opeffVar0Val0 & opeffVar0Val1) | (opeffVar0Val0 & opeffVar0Val2) | (opeffVar0Val1 & opeffVar0Val2))
# Evaluated 4 models
# 265
# nia_pi_pn
# oppreVar0Val0 & oppreVar0Val1 & oppreVar0Val2 & ~oppreVar0Val0 & ((opeffVar0Val0 & opeffVar0Val1) | (opeffVar0Val0 & opeffVar0Val2) | (opeffVar0Val1 & opeffVar0Val2))
# 1
# ia_pd_pn
# oppreVar0Val0 & ((opeffVar0Val0 & opeffVar0Val1) | (opeffVar0Val0 & opeffVar0Val2) | (opeffVar0Val1 & opeffVar0Val2))
# Evaluated 4 models
# 316
# nia_pd_pn
# ~oppreVar0Val0 & ((opeffVar0Val0 & opeffVar0Val1) | (opeffVar0Val0 & opeffVar0Val2) | (opeffVar0Val1 & opeffVar0Val2))
# Evaluated 4 models
# 27
# Compute: 1,4
# ts
# 65535
# ia
# oppreVar0Val0
# Evaluated 1 models
# 61440
# nia
# ~oppreVar0Val0
# Evaluated 1 models
# 4095
# pi
# oppreVar0Val0 & oppreVar0Val1 & oppreVar0Val2 & oppreVar0Val3
# Evaluated 1 models
# 50625
# pd
# True
# Evaluated 1 models
# 65535
# pn
# (opeffVar0Val0 & opeffVar0Val1) | (opeffVar0Val0 & opeffVar0Val2) | (opeffVar0Val0 & opeffVar0Val3) | (opeffVar0Val1 & opeffVar0Val2) | (opeffVar0Val1 & opeffVar0Val3) | (opeffVar0Val2 & opeffVar0Val3)
# Evaluated 11 models
# 50625
# ia_pi
# oppreVar0Val0 & oppreVar0Val1 & oppreVar0Val2 & oppreVar0Val3
# Evaluated 1 models
# 50625
# nia_pi
# oppreVar0Val0 & oppreVar0Val1 & oppreVar0Val2 & oppreVar0Val3 & ~oppreVar0Val0
# 1
# ia_pd
# oppreVar0Val0
# Evaluated 1 models
# 61440
# nia_pd
# ~oppreVar0Val0
# Evaluated 1 models
# 4095
# ia_pn
# oppreVar0Val0 & ((opeffVar0Val0 & opeffVar0Val1) | (opeffVar0Val0 & opeffVar0Val2) | (opeffVar0Val0 & opeffVar0Val3) | (opeffVar0Val1 & opeffVar0Val2) | (opeffVar0Val1 & opeffVar0Val3) | (opeffVar0Val2 & opeffVar0Val3))
# Evaluated 11 models
# 48224
# nia_pn
# ~oppreVar0Val0 & ((opeffVar0Val0 & opeffVar0Val1) | (opeffVar0Val0 & opeffVar0Val2) | (opeffVar0Val0 & opeffVar0Val3) | (opeffVar0Val1 & opeffVar0Val2) | (opeffVar0Val1 & opeffVar0Val3) | (opeffVar0Val2 & opeffVar0Val3))
# Evaluated 11 models
# 2401
# pi_pn
# oppreVar0Val0 & oppreVar0Val1 & oppreVar0Val2 & oppreVar0Val3 & ((opeffVar0Val0 & opeffVar0Val1) | (opeffVar0Val0 & opeffVar0Val2) | (opeffVar0Val0 & opeffVar0Val3) | (opeffVar0Val1 & opeffVar0Val2) | (opeffVar0Val1 & opeffVar0Val3) | (opeffVar0Val2 & opeffVar0Val3))
# Evaluated 11 models
# 41503
# pd_pn
# (opeffVar0Val0 & opeffVar0Val1) | (opeffVar0Val0 & opeffVar0Val2) | (opeffVar0Val0 & opeffVar0Val3) | (opeffVar0Val1 & opeffVar0Val2) | (opeffVar0Val1 & opeffVar0Val3) | (opeffVar0Val2 & opeffVar0Val3)
# Evaluated 11 models
# 50625
# ia_pi_pn
# oppreVar0Val0 & oppreVar0Val1 & oppreVar0Val2 & oppreVar0Val3 & ((opeffVar0Val0 & opeffVar0Val1) | (opeffVar0Val0 & opeffVar0Val2) | (opeffVar0Val0 & opeffVar0Val3) | (opeffVar0Val1 & opeffVar0Val2) | (opeffVar0Val1 & opeffVar0Val3) | (opeffVar0Val2 & opeffVar0Val3))
# Evaluated 11 models
# 41503
# nia_pi_pn
# oppreVar0Val0 & oppreVar0Val1 & oppreVar0Val2 & oppreVar0Val3 & ~oppreVar0Val0 & ((opeffVar0Val0 & opeffVar0Val1) | (opeffVar0Val0 & opeffVar0Val2) | (opeffVar0Val0 & opeffVar0Val3) | (opeffVar0Val1 & opeffVar0Val2) | (opeffVar0Val1 & opeffVar0Val3) | (opeffVar0Val2 & opeffVar0Val3))
# 1
# ia_pd_pn
# oppreVar0Val0 & ((opeffVar0Val0 & opeffVar0Val1) | (opeffVar0Val0 & opeffVar0Val2) | (opeffVar0Val0 & opeffVar0Val3) | (opeffVar0Val1 & opeffVar0Val2) | (opeffVar0Val1 & opeffVar0Val3) | (opeffVar0Val2 & opeffVar0Val3))
# Evaluated 11 models
# 48224
# nia_pd_pn
# ~oppreVar0Val0 & ((opeffVar0Val0 & opeffVar0Val1) | (opeffVar0Val0 & opeffVar0Val2) | (opeffVar0Val0 & opeffVar0Val3) | (opeffVar0Val1 & opeffVar0Val2) | (opeffVar0Val1 & opeffVar0Val3) | (opeffVar0Val2 & opeffVar0Val3))
# Evaluated 11 models
# 2401
# Compute: 1,5
# ts
# 33554431
# ia
# oppreVar0Val0
# Evaluated 1 models
# 32505856
# nia
# ~oppreVar0Val0
# Evaluated 1 models
# 1048575
# pi
# oppreVar0Val0 & oppreVar0Val1 & oppreVar0Val2 & oppreVar0Val3 & oppreVar0Val4
# Evaluated 1 models
# 28629151
# pd
# True
# Evaluated 1 models
# 33554431
# pn
# (opeffVar0Val0 & opeffVar0Val1) | (opeffVar0Val0 & opeffVar0Val2) | (opeffVar0Val0 & opeffVar0Val3) | (opeffVar0Val0 & opeffVar0Val4) | (opeffVar0Val1 & opeffVar0Val2) | (opeffVar0Val1 & opeffVar0Val3) | (opeffVar0Val1 & opeffVar0Val4) | (opeffVar0Val2 & opeffVar0Val3) | (opeffVar0Val2 & opeffVar0Val4) | (opeffVar0Val3 & opeffVar0Val4)
# Evaluated 26 models
# 28629151
# ia_pi
# oppreVar0Val0 & oppreVar0Val1 & oppreVar0Val2 & oppreVar0Val3 & oppreVar0Val4
# Evaluated 1 models
# 28629151
# nia_pi
# oppreVar0Val0 & oppreVar0Val1 & oppreVar0Val2 & oppreVar0Val3 & oppreVar0Val4 & ~oppreVar0Val0
# 1
# ia_pd
# oppreVar0Val0
# Evaluated 1 models
# 32505856
# nia_pd
# ~oppreVar0Val0
# Evaluated 1 models
# 1048575
# ia_pn
# oppreVar0Val0 & ((opeffVar0Val0 & opeffVar0Val1) | (opeffVar0Val0 & opeffVar0Val2) | (opeffVar0Val0 & opeffVar0Val3) | (opeffVar0Val0 & opeffVar0Val4) | (opeffVar0Val1 & opeffVar0Val2) | (opeffVar0Val1 & opeffVar0Val3) | (opeffVar0Val1 & opeffVar0Val4) | (opeffVar0Val2 & opeffVar0Val3) | (opeffVar0Val2 & opeffVar0Val4) | (opeffVar0Val3 & opeffVar0Val4))
# Evaluated 26 models
# 27869776
# nia_pn
# ~oppreVar0Val0 & ((opeffVar0Val0 & opeffVar0Val1) | (opeffVar0Val0 & opeffVar0Val2) | (opeffVar0Val0 & opeffVar0Val3) | (opeffVar0Val0 & opeffVar0Val4) | (opeffVar0Val1 & opeffVar0Val2) | (opeffVar0Val1 & opeffVar0Val3) | (opeffVar0Val1 & opeffVar0Val4) | (opeffVar0Val2 & opeffVar0Val3) | (opeffVar0Val2 & opeffVar0Val4) | (opeffVar0Val3 & opeffVar0Val4))
# Evaluated 26 models
# 759375
# pi_pn
# oppreVar0Val0 & oppreVar0Val1 & oppreVar0Val2 & oppreVar0Val3 & oppreVar0Val4 & ((opeffVar0Val0 & opeffVar0Val1) | (opeffVar0Val0 & opeffVar0Val2) | (opeffVar0Val0 & opeffVar0Val3) | (opeffVar0Val0 & opeffVar0Val4) | (opeffVar0Val1 & opeffVar0Val2) | (opeffVar0Val1 & opeffVar0Val3) | (opeffVar0Val1 & opeffVar0Val4) | (opeffVar0Val2 & opeffVar0Val3) | (opeffVar0Val2 & opeffVar0Val4) | (opeffVar0Val3 & opeffVar0Val4))
# Evaluated 26 models
# 24997921
# pd_pn
# (opeffVar0Val0 & opeffVar0Val1) | (opeffVar0Val0 & opeffVar0Val2) | (opeffVar0Val0 & opeffVar0Val3) | (opeffVar0Val0 & opeffVar0Val4) | (opeffVar0Val1 & opeffVar0Val2) | (opeffVar0Val1 & opeffVar0Val3) | (opeffVar0Val1 & opeffVar0Val4) | (opeffVar0Val2 & opeffVar0Val3) | (opeffVar0Val2 & opeffVar0Val4) | (opeffVar0Val3 & opeffVar0Val4)
# Evaluated 26 models
# 28629151
# ia_pi_pn
# oppreVar0Val0 & oppreVar0Val1 & oppreVar0Val2 & oppreVar0Val3 & oppreVar0Val4 & ((opeffVar0Val0 & opeffVar0Val1) | (opeffVar0Val0 & opeffVar0Val2) | (opeffVar0Val0 & opeffVar0Val3) | (opeffVar0Val0 & opeffVar0Val4) | (opeffVar0Val1 & opeffVar0Val2) | (opeffVar0Val1 & opeffVar0Val3) | (opeffVar0Val1 & opeffVar0Val4) | (opeffVar0Val2 & opeffVar0Val3) | (opeffVar0Val2 & opeffVar0Val4) | (opeffVar0Val3 & opeffVar0Val4))
# Evaluated 26 models
# 24997921
# nia_pi_pn
# oppreVar0Val0 & oppreVar0Val1 & oppreVar0Val2 & oppreVar0Val3 & oppreVar0Val4 & ~oppreVar0Val0 & ((opeffVar0Val0 & opeffVar0Val1) | (opeffVar0Val0 & opeffVar0Val2) | (opeffVar0Val0 & opeffVar0Val3) | (opeffVar0Val0 & opeffVar0Val4) | (opeffVar0Val1 & opeffVar0Val2) | (opeffVar0Val1 & opeffVar0Val3) | (opeffVar0Val1 & opeffVar0Val4) | (opeffVar0Val2 & opeffVar0Val3) | (opeffVar0Val2 & opeffVar0Val4) | (opeffVar0Val3 & opeffVar0Val4))
# 1
# ia_pd_pn
# oppreVar0Val0 & ((opeffVar0Val0 & opeffVar0Val1) | (opeffVar0Val0 & opeffVar0Val2) | (opeffVar0Val0 & opeffVar0Val3) | (opeffVar0Val0 & opeffVar0Val4) | (opeffVar0Val1 & opeffVar0Val2) | (opeffVar0Val1 & opeffVar0Val3) | (opeffVar0Val1 & opeffVar0Val4) | (opeffVar0Val2 & opeffVar0Val3) | (opeffVar0Val2 & opeffVar0Val4) | (opeffVar0Val3 & opeffVar0Val4))
# Evaluated 26 models
# 27869776
# nia_pd_pn
# ~oppreVar0Val0 & ((opeffVar0Val0 & opeffVar0Val1) | (opeffVar0Val0 & opeffVar0Val2) | (opeffVar0Val0 & opeffVar0Val3) | (opeffVar0Val0 & opeffVar0Val4) | (opeffVar0Val1 & opeffVar0Val2) | (opeffVar0Val1 & opeffVar0Val3) | (opeffVar0Val1 & opeffVar0Val4) | (opeffVar0Val2 & opeffVar0Val3) | (opeffVar0Val2 & opeffVar0Val4) | (opeffVar0Val3 & opeffVar0Val4))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-e8395968ba51> in <module>()
#     149         f_nia_pd_pn = ~opInitApplicableInState('op') & opPrivatelyDependent('op',1) & opPrivatelyNondeterministic('op',1)
#     150         print(f_nia_pd_pn)
# --> 151         models_nia_pd_pn = satisfiable(f_nia_pd_pn,all_models=True)
#     152         ts_nia_pd_pn = evaluateModels(models_nia_pd_pn)
#     153         print(ts_nia_pd_pn)
#
# /usr/local/lib/python3.5/dist-packages/sympy/logic/inference.py in satisfiable(expr, algorithm, all_models)
#      78
#      79     """
# ---> 80     expr = to_cnf(expr)
#      81     if algorithm == "dpll":
#      82         from sympy.logic.algorithms.dpll import dpll_satisfiable
#
# /usr/local/lib/python3.5/dist-packages/sympy/logic/boolalg.py in to_cnf(expr, simplify)
#    1334
#    1335     expr = eliminate_implications(expr)
# -> 1336     return distribute_and_over_or(expr)
#    1337
#    1338
#
# /usr/local/lib/python3.5/dist-packages/sympy/logic/boolalg.py in distribute_and_over_or(expr)
#    1241     (A | ~B) & (A | ~C)
#    1242     """
# -> 1243     return _distribute((expr, And, Or))
#    1244
#    1245
#
# /usr/local/lib/python3.5/dist-packages/sympy/logic/boolalg.py in _distribute(info)
#    1278     elif isinstance(info[0], info[1]):
#    1279         return info[1](*list(map(_distribute,
# -> 1280             [(x, info[1], info[2]) for x in info[0].args])))
#    1281     else:
#    1282         return info[0]
#
# /usr/local/lib/python3.5/dist-packages/sympy/logic/boolalg.py in _distribute(info)
#    1275         rest = info[2](*[a for a in info[0].args if a is not conj])
#    1276         return info[1](*list(map(_distribute,
# -> 1277             [(info[2](c, rest), info[1], info[2]) for c in conj.args])))
#    1278     elif isinstance(info[0], info[1]):
#    1279         return info[1](*list(map(_distribute,
#
# /usr/local/lib/python3.5/dist-packages/sympy/logic/boolalg.py in _distribute(info)
#    1275         rest = info[2](*[a for a in info[0].args if a is not conj])
#    1276         return info[1](*list(map(_distribute,
# -> 1277             [(info[2](c, rest), info[1], info[2]) for c in conj.args])))
#    1278     elif isinstance(info[0], info[1]):
#    1279         return info[1](*list(map(_distribute,
#
# /usr/local/lib/python3.5/dist-packages/sympy/logic/boolalg.py in _distribute(info)
#    1275         rest = info[2](*[a for a in info[0].args if a is not conj])
#    1276         return info[1](*list(map(_distribute,
# -> 1277             [(info[2](c, rest), info[1], info[2]) for c in conj.args])))
#    1278     elif isinstance(info[0], info[1]):
#    1279         return info[1](*list(map(_distribute,
#
# /usr/local/lib/python3.5/dist-packages/sympy/logic/boolalg.py in _distribute(info)
#    1275         rest = info[2](*[a for a in info[0].args if a is not conj])
#    1276         return info[1](*list(map(_distribute,
# -> 1277             [(info[2](c, rest), info[1], info[2]) for c in conj.args])))
#    1278     elif isinstance(info[0], info[1]):
#    1279         return info[1](*list(map(_distribute,
#
# /usr/local/lib/python3.5/dist-packages/sympy/logic/boolalg.py in _distribute(info)
#    1275         rest = info[2](*[a for a in info[0].args if a is not conj])
#    1276         return info[1](*list(map(_distribute,
# -> 1277             [(info[2](c, rest), info[1], info[2]) for c in conj.args])))
#    1278     elif isinstance(info[0], info[1]):
#    1279         return info[1](*list(map(_distribute,
#
# /usr/local/lib/python3.5/dist-packages/sympy/logic/boolalg.py in _distribute(info)
#    1275         rest = info[2](*[a for a in info[0].args if a is not conj])
#    1276         return info[1](*list(map(_distribute,
# -> 1277             [(info[2](c, rest), info[1], info[2]) for c in conj.args])))
#    1278     elif isinstance(info[0], info[1]):
#    1279         return info[1](*list(map(_distribute,
#
# /usr/local/lib/python3.5/dist-packages/sympy/logic/boolalg.py in _distribute(info)
#    1275         rest = info[2](*[a for a in info[0].args if a is not conj])
#    1276         return info[1](*list(map(_distribute,
# -> 1277             [(info[2](c, rest), info[1], info[2]) for c in conj.args])))
#    1278     elif isinstance(info[0], info[1]):
#    1279         return info[1](*list(map(_distribute,
#
# /usr/local/lib/python3.5/dist-packages/sympy/logic/boolalg.py in <listcomp>(.0)
#    1275         rest = info[2](*[a for a in info[0].args if a is not conj])
#    1276         return info[1](*list(map(_distribute,
# -> 1277             [(info[2](c, rest), info[1], info[2]) for c in conj.args])))
#    1278     elif isinstance(info[0], info[1]):
#    1279         return info[1](*list(map(_distribute,
#
# /usr/local/lib/python3.5/dist-packages/sympy/core/operations.py in __new__(cls, *args, **options)
#     409             # is done so short-circuiting can be done
#     410             # without having to sympify all values
# --> 411             _args = frozenset(cls._new_args_filter(args))
#     412         except ShortCircuit:
#     413             return sympify(cls.zero)
#
# /usr/local/lib/python3.5/dist-packages/sympy/logic/boolalg.py in _new_args_filter(cls, args)
#     583         newargs = []
#     584         rel = []
# --> 585         args = BooleanFunction.binary_check_and_simplify(*args)
#     586         for x in args:
#     587             if x.is_Relational:
#
# /usr/local/lib/python3.5/dist-packages/sympy/logic/boolalg.py in binary_check_and_simplify(self, *args)
#     432         from sympy.core.relational import Relational, Eq, Ne
#     433         args = [as_Boolean(i) for i in args]
# --> 434         bin = set().union(*[i.binary_symbols for i in args])
#     435         rel = set().union(*[i.atoms(Relational) for i in args])
#     436         reps = {}
#
# /usr/local/lib/python3.5/dist-packages/sympy/logic/boolalg.py in <listcomp>(.0)
#     432         from sympy.core.relational import Relational, Eq, Ne
#     433         args = [as_Boolean(i) for i in args]
# --> 434         bin = set().union(*[i.binary_symbols for i in args])
#     435         rel = set().union(*[i.atoms(Relational) for i in args])
#     436         reps = {}
#
# /usr/local/lib/python3.5/dist-packages/sympy/logic/boolalg.py in binary_symbols(self)
#     162     def binary_symbols(self):
#     163         from sympy.core.relational import Eq, Ne
# --> 164         return set().union(*[i.binary_symbols for i in self.args
#     165             if i.is_Boolean or i.is_Symbol
#     166             or isinstance(i, (Eq, Ne))])
#
# /usr/local/lib/python3.5/dist-packages/sympy/logic/boolalg.py in <listcomp>(.0)
#     164         return set().union(*[i.binary_symbols for i in self.args
#     165             if i.is_Boolean or i.is_Symbol
# --> 166             or isinstance(i, (Eq, Ne))])
#     167
#     168
#
# /usr/local/lib/python3.5/dist-packages/sympy/logic/boolalg.py in binary_symbols(self)
#     161     @property
#     162     def binary_symbols(self):
# --> 163         from sympy.core.relational import Eq, Ne
#     164         return set().union(*[i.binary_symbols for i in self.args
#     165             if i.is_Boolean or i.is_Symbol
#
# /usr/lib/python3.5/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_)
#
# KeyboardInterrupt:
